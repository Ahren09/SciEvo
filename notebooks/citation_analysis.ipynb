# %% [markdown]
# ## Citation Analysis
#
# In this notebook, we analyze the citation patterns for each selected topic.

# %%
from collections import defaultdict
from datetime import datetime
import pytz
import os
import sys
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

# %%
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('.'))

# %%
os.path.abspath('.')
# Out:
# '/Users/ahren/Workspace/NLP/arXivData/notebooks'

# %%
import const
from arguments import parse_args
from utility.metrics import calculate_citation_diversity
from utility.utils_data import load_semantic_scholar_papers, \
    load_semantic_scholar_references_parquet, load_keywords, load_arXiv_data
from utility.utils_misc import project_setup
from utility.utils_time import time_difference_in_days

# %%
# Calculate average age of citations for all types of references


data_dir = os.path.expanduser("~/Workspace/data")
semantic_scholar_papers = load_semantic_scholar_papers(data_dir)
arxiv_data = load_arXiv_data(data_dir)
# Out:
# Loaded 2022476 entries from Semantic Scholar.
# Loaded 2118385 arXiv papers in 10.497 secs.
# /Users/ahren/Workspace/NLP/arXivData/utility/utils_data.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column_name].fillna("", inplace=True)

# %%
for year in range(2023, 2024):
    references_one_year = load_semantic_scholar_references_parquet(year, data_dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 for year in range(2023, 2024):
# ----> 2     references_one_year = load_semantic_scholar_references_parquet(year, data_dir)
#
# File ~/Workspace/NLP/arXivData/utility/utils_data.py:213, in load_semantic_scholar_references_parquet(data_dir, start_year, end_year)
#     202 """Loads Semantic Scholar references from parquet files within the specified year range.
#     203
#     204 Args:
#    (...)
#     210     pd.DataFrame: A DataFrame containing all the references from the specified year range.
#     211 """
#     212 if end_year is None:
# --> 213     end_year = start_year + 1
#     215 current_year = start_year
#     216 all_references: List[pd.DataFrame] = []
#
# TypeError: can only concatenate str (not "int") to str

# %%
reference_one_paper = references_one_year.iloc[0]

# %%
feature_name = "title_and_abstract"

mask = {}
for index_row, row in tqdm(arxiv_data.iterrows(), total=len(arxiv_data)):
    # print(row)
    contains_keywords = False
    # for keyword in const.SUBJECT2KEYWORDS['Computer Science'][8]:
    keywords_one_paper = set([kwd.strip().lower() for kwd in row[f"{feature_name}_keywords"].split(',')])

    for keyword in const.SUBJECT2KEYWORDS['Computer Science'][8]:
        # print(keywords_one_paper)
        
        if keyword.lower() in keywords_one_paper:
            contains_keywords = True
            # print(keyword)
            
    id = row['id']
    # id = row['id'].split("arxiv.org/abs/")[-1]
    # if id[-2] == 'v':
    #     id = id[:-2]

    # elif id[-3] == 'v':
    #     id = id[:-3]
    
    mask[id] = contains_keywords

# %%
const.SUBJECT2KEYWORDS['Computer Science'][8]
# Out:
# ('large language models',
#  'llm',
#  'llms',
#  'gpt',
#  'chatgpt',
#  'gpt4',
#  'gpt3',
#  'gpt-4',
#  'gpt-3',
#  'rlhf',
#  'chain-of-thought',
#  'chain of thought',
#  'chain of thoughts',
#  'cot')

# %%
sum(mask.values())
# Out:
# 14733

# %%
mask = pd.Series(mask)

# %%
mask
# Out:
# http://arxiv.org/abs/physics/9403001      False
# http://arxiv.org/abs/physics/9403001v1    False
# http://arxiv.org/abs/math/9201239         False
# http://arxiv.org/abs/math/9201204         False
# http://arxiv.org/abs/math/9201203         False
#                                           ...
# http://arxiv.org/abs/2406.16863v1         False
# http://arxiv.org/abs/2406.16864v1         False
# http://arxiv.org/abs/2406.16865v1         False
# http://arxiv.org/abs/2406.16866v1         False
# http://arxiv.org/abs/2406.16867v1         False
# Length: 2118385, dtype: bool

# %%
arxiv_data[mask.index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 arxiv_data[mask.index]
#
# File /opt/anaconda3/envs/llama/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/llama/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/llama/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['physics/9403001', 'math/9201239', 'math/9201204', 'math/9201203',\n       'math/9201205', 'math/9201206', 'math/9201207', 'cs/9301111',\n       'math/9201240', 'math/9201241',\n       ...\n       '2406.16858', '2406.16859', '2406.16860', '2406.16861', '2406.16862',\n       '2406.16863', '2406.16864', '2406.16865', '2406.16866', '2406.16867'],\n      dtype='object', length=2042914)] are in the [columns]"

# %%
arxiv_data.set_index('id').loc[mask.index.values]
# Out:
#                                                                                     title  \
# id
# http://arxiv.org/abs/physics/9403001                     Desperately Seeking Superstrings
# http://arxiv.org/abs/physics/9403001v1                   Desperately Seeking Superstrings
# http://arxiv.org/abs/math/9201239                           A note on canonical functions
# http://arxiv.org/abs/math/9201204                                Shadows of convex bodies
# http://arxiv.org/abs/math/9201203                            Convex bodies with few faces
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       FreeTraj: Tuning-Free Trajectory Control in Vi...
# http://arxiv.org/abs/2406.16864v1       StableNormal: Reducing Diffusion Variance for ...
# http://arxiv.org/abs/2406.16865v1       Variational Monte Carlo Study of the Doped $t$...
# http://arxiv.org/abs/2406.16866v1       Revisiting Referring Expression Comprehension ...
# http://arxiv.org/abs/2406.16867v1       Normalization of ZZ instanton amplitudes in ty...
#
#                                                                                   summary  \
# id
# http://arxiv.org/abs/physics/9403001    We provide a detailed analysis of the problems...
# http://arxiv.org/abs/physics/9403001v1  We provide a detailed analysis of the problems...
# http://arxiv.org/abs/math/9201239       We construct a generic extension in which the ...
# http://arxiv.org/abs/math/9201204       It is proved that if $C$ is a convex body in $...
# http://arxiv.org/abs/math/9201203       It is proved that if $u_1,\ldots, u_n$ are vec...
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       Diffusion model has demonstrated remarkable ca...
# http://arxiv.org/abs/2406.16864v1       This work addresses the challenge of high-qual...
# http://arxiv.org/abs/2406.16865v1       The ground state of the bipartite $t$-$J$ mode...
# http://arxiv.org/abs/2406.16866v1       Referring expression comprehension (REC) invol...
# http://arxiv.org/abs/2406.16867v1       We study ZZ instanton corrections in the $(2,4...
#
#                                                                             arxiv_comment  \
# id
# http://arxiv.org/abs/physics/9403001    originally appeared as a Reference Frame in Ph...
# http://arxiv.org/abs/physics/9403001v1  originally appeared as a Reference Frame in Ph...
# http://arxiv.org/abs/math/9201239
# http://arxiv.org/abs/math/9201204
# http://arxiv.org/abs/math/9201203
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       Project Page: http://haonanqiu.com/projects/Fr...
# http://arxiv.org/abs/2406.16864v1       HF Demo: hf.co/Stable-X, Video:\n  https://www...
# http://arxiv.org/abs/2406.16865v1                                    14 pages, 11 figures
# http://arxiv.org/abs/2406.16866v1
# http://arxiv.org/abs/2406.16867v1       27 pages of main text + 27 pages of appendices...
#
#                                                        published  \
# id
# http://arxiv.org/abs/physics/9403001   1986-04-25 15:39:49+00:00
# http://arxiv.org/abs/physics/9403001v1 1986-04-25 15:39:49+00:00
# http://arxiv.org/abs/math/9201239      1989-04-15 00:00:00+00:00
# http://arxiv.org/abs/math/9201204      1989-10-26 14:59:00+00:00
# http://arxiv.org/abs/math/9201203      1989-10-26 14:59:00+00:00
# ...                                                          ...
# http://arxiv.org/abs/2406.16863v1      2024-06-24 17:59:56+00:00
# http://arxiv.org/abs/2406.16864v1      2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16865v1      2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16866v1      2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16867v1      2024-06-24 17:59:59+00:00
#
#                                                           updated  \
# id
# http://arxiv.org/abs/physics/9403001    1986-04-25 15:39:49+00:00
# http://arxiv.org/abs/physics/9403001v1  1986-04-25 15:39:49+00:00
# http://arxiv.org/abs/math/9201239       1989-04-15 00:00:00+00:00
# http://arxiv.org/abs/math/9201204       1989-10-26 14:59:00+00:00
# http://arxiv.org/abs/math/9201203       1989-10-26 14:59:00+00:00
# ...                                                           ...
# http://arxiv.org/abs/2406.16863v1       2024-06-24 17:59:56+00:00
# http://arxiv.org/abs/2406.16864v1       2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16865v1       2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16866v1       2024-06-24 17:59:58+00:00
# http://arxiv.org/abs/2406.16867v1       2024-06-24 17:59:59+00:00
#
#                                                                                   authors  \
# id
# http://arxiv.org/abs/physics/9403001                 ['Paul Ginsparg', 'Sheldon Glashow']
# http://arxiv.org/abs/physics/9403001v1               ['Paul Ginsparg', 'Sheldon Glashow']
# http://arxiv.org/abs/math/9201239                       ['Thomas Jech', 'Saharon Shelah']
# http://arxiv.org/abs/math/9201204                                          ['Keith Ball']
# http://arxiv.org/abs/math/9201203                           ['Keith Ball', 'Alain Pajor']
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       ['Haonan Qiu', 'Zhaoxi Chen', 'Zhouxia Wang', ...
# http://arxiv.org/abs/2406.16864v1       ['Chongjie Ye', 'Lingteng Qiu', 'Xiaodong Gu',...
# http://arxiv.org/abs/2406.16865v1            ['Can Cui', 'Jing-Yu Zhao', 'Zheng-Yu Weng']
# http://arxiv.org/abs/2406.16866v1       ['Jierun Chen', 'Fangyun Wei', 'Jinjing Zhao',...
# http://arxiv.org/abs/2406.16867v1       ['Vivek Chakrabhavi', 'Dan Stefan Eniceicu', '...
#
#                                                                     tags  \
# id
# http://arxiv.org/abs/physics/9403001            [physics.pop-ph, hep-th]
# http://arxiv.org/abs/physics/9403001v1          [physics.pop-ph, hep-th]
# http://arxiv.org/abs/math/9201239                              [math.LO]
# http://arxiv.org/abs/math/9201204       [math.MG, math.FA, 52A20, 52A40]
# http://arxiv.org/abs/math/9201203       [math.MG, math.FA, 52A20, 10E05]
# ...                                                                  ...
# http://arxiv.org/abs/2406.16863v1                                [cs.CV]
# http://arxiv.org/abs/2406.16864v1                  [cs.CV, cs.AI, cs.GR]
# http://arxiv.org/abs/2406.16865v1                      [cond-mat.str-el]
# http://arxiv.org/abs/2406.16866v1                                [cs.CV]
# http://arxiv.org/abs/2406.16867v1                               [hep-th]
#
#                                                             tags_cleaned  \
# id
# http://arxiv.org/abs/physics/9403001            [physics.pop-ph, hep-th]
# http://arxiv.org/abs/physics/9403001v1          [physics.pop-ph, hep-th]
# http://arxiv.org/abs/math/9201239                              [math.LO]
# http://arxiv.org/abs/math/9201204       [math.MG, math.FA, 52A20, 52A40]
# http://arxiv.org/abs/math/9201203       [math.MG, math.FA, 52A20, 10E05]
# ...                                                                  ...
# http://arxiv.org/abs/2406.16863v1                                   None
# http://arxiv.org/abs/2406.16864v1                                   None
# http://arxiv.org/abs/2406.16865v1                                   None
# http://arxiv.org/abs/2406.16866v1                                   None
# http://arxiv.org/abs/2406.16867v1                                   None
#
#                                                                            title_keywords  \
# id
# http://arxiv.org/abs/physics/9403001         Superstrings, String theory, Quantum gravity
# http://arxiv.org/abs/physics/9403001v1               Superstrings, String theory, Physics
# http://arxiv.org/abs/math/9201239       canonical functions, algebraic geometry, birat...
# http://arxiv.org/abs/math/9201204                        Convex bodies, Shadows, Geometry
# http://arxiv.org/abs/math/9201203                      Convex bodies, Few faces, Geometry
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       Trajectory Control, Video Diffusion Models, Tu...
# http://arxiv.org/abs/2406.16864v1         Diffusion Variance, Stable Normal, Sharp Normal
# http://arxiv.org/abs/2406.16865v1       Variational Monte Carlo, Doped t-J Model, Hone...
# http://arxiv.org/abs/2406.16866v1       Referring Expression Comprehension, Evaluation...
# http://arxiv.org/abs/2406.16867v1       Instanton amplitudes, Type 0B superstring theo...
#
#                                                               title_and_abstract_keywords
# id
# http://arxiv.org/abs/physics/9403001    superstring theory, theoretical physics, quant...
# http://arxiv.org/abs/physics/9403001v1  superstring theory, theoretical physics, quant...
# http://arxiv.org/abs/math/9201239       canonical functions, generic extension, aleph_...
# http://arxiv.org/abs/math/9201204       convex bodies, shadows, affine image, orthogon...
# http://arxiv.org/abs/math/9201203       Convex bodies, Faces, Vectors, Volume, Symmetr...
# ...                                                                                   ...
# http://arxiv.org/abs/2406.16863v1       Diffusion model, video generation, trajectory ...
# http://arxiv.org/abs/2406.16864v1       surface normal estimation, diffusion priors, d...
# http://arxiv.org/abs/2406.16865v1       Variational Monte Carlo, Doped t-J Model, Hone...
# http://arxiv.org/abs/2406.16866v1       Referring expression comprehension, Large mult...
# http://arxiv.org/abs/2406.16867v1       ZZ instanton amplitudes, type 0B minimal super...
#
# [2118385 rows x 10 columns]

# %%
arxiv_data.set_index('id').loc[['http://arxiv.org/abs/physics/9403001']]
# Out:
#                                                                  title  \
# id
# http://arxiv.org/abs/physics/9403001  Desperately Seeking Superstrings
#
#                                                                                 summary  \
# id
# http://arxiv.org/abs/physics/9403001  We provide a detailed analysis of the problems...
#
#                                                                           arxiv_comment  \
# id
# http://arxiv.org/abs/physics/9403001  originally appeared as a Reference Frame in Ph...
#
#                                                      published  \
# id
# http://arxiv.org/abs/physics/9403001 1986-04-25 15:39:49+00:00
#
#                                                         updated  \
# id
# http://arxiv.org/abs/physics/9403001  1986-04-25 15:39:49+00:00
#
#                                                                    authors  \
# id
# http://arxiv.org/abs/physics/9403001  ['Paul Ginsparg', 'Sheldon Glashow']
#
#                                                           tags  \
# id
# http://arxiv.org/abs/physics/9403001  [physics.pop-ph, hep-th]
#
#                                                   tags_cleaned  \
# id
# http://arxiv.org/abs/physics/9403001  [physics.pop-ph, hep-th]
#
#                                                                     title_keywords  \
# id
# http://arxiv.org/abs/physics/9403001  Superstrings, String theory, Quantum gravity
#
#                                                             title_and_abstract_keywords
# id
# http://arxiv.org/abs/physics/9403001  superstring theory, theoretical physics, quant...

# %%
total_age = 0
count = 0

# Set a specific timezone, e.g., UTC
timezone = pytz.timezone('UTC')

all_time_differences = []

for paper in reference_one_paper.references:
    # print(paper)
    # print(paper['citedPaper']['publicationDate'])
    timestamp_reference = timezone.localize(datetime.strptime(paper['citedPaper']['publicationDate'], "%Y-%m-%d"))
    all_time_differences += [(reference_one_paper['arXivPublicationDate'] - timestamp_reference)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 12
#       7 all_time_differences = []
#       9 for paper in reference_one_paper.references:
#      10     # print(paper)
#      11     # print(paper['citedPaper']['publicationDate'])
# ---> 12     timestamp_reference = timezone.localize(datetime.strptime(paper['citedPaper']['publicationDate'], "%Y-%m-%d"))
#      13     all_time_differences += [(reference_one_paper['arXivPublicationDate'] - timestamp_reference)]
#
# TypeError: strptime() argument 1 must be str, not None
